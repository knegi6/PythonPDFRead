# %%
import pandas as pd
master_csv= (r"\\Bpspfilnor401\BluePrism\GAFG\GAFG_AgentB_Indexing\4_13_2022\Master_Excel_AgentB_4_13_2022.csv")
master_excel= (r"\\Bpspfilnor401\BluePrism\GAFG\GAFG_AgentB_Indexing\4_13_2022\Master_Excel_AgentB_4_13_2022.xlsx")

df=pd.read_csv(master_csv)
# df=pd.read_excel(master_excel)
# df=pd.read_csv(master_excel)
# print(df)

# %%
import files_folder_operations as ffo
ff=ffo.FilesAndFolderOperations() 

import pdf_read as pdfr

import pdf_read as pdfr
import files_folder_operations as ffo
import pandas as pd
pfr=pdfr.PdfRead()


agent_code_dictionary={"Path":"Agent Code"}


# files = ff.get_files_recursively(r"\\Bpspfilnor401\BluePrism\GAFG\GAFG_AgentB_Indexing\4_7_2022\SPLIT\April 2022 AML Term Notice_Clean-up.pdf_SPLIT_FOLDER")
# print(files)
# filess=[]
# filess=files
# print(filess)

import glob
file_list = glob.glob(r"\\Bpspfilnor401\BluePrism\GAFG\GAFG_AgentB_Indexing\4_13_2022\SPLIT\Debt rolled to Upline_ALL_April 2022.pdf_SPLIT_FOLDER\*pdf")
print(file_list)
print(agent_code_dictionary)

# %%
import camelot as cam
# import ghostscript
import os

for file in file_list:
    #source: file:///C://Users//kulra//OneDrive/Desktop/ilovepdf_split/12%202021%20120%20Day%20OS%20Checks%2005%2018%2021%20to%2008%2007%2021%20%20143%202%20pg-1.pdf
    table = cam.read_pdf(file, pages = '1', flavor = 'stream')
    table[0].df.iat[0,1]
    print(table[0].df.iat[0,1])

def get_top_right_agent_code(file):
    #source: file:///C://Users//kulra//OneDrive/Desktop/ilovepdf_split/12%202021%20120%20Day%20OS%20Checks%2005%2018%2021%20to%2008%2007%2021%20%20143%202%20pg-1.pdf
    table = cam.read_pdf(file, pages = '1', flavor = 'stream')
    top_right_agent_code = table[0].df.iat[0,1]
    print(table[0].df.iat[0,1])
    return top_right_agent_code

# %%
import excel_others_operations as eoo
import pdf_read as pdfr
import glob 


pfr=pdfr.PdfRead()
eop=eoo.ExcelAndPandasOperation()


agent_code_dict={"Path": ["Agent Code" , "Top Right Agent Code"]}

input_file_path =(r"\\Bpspfilnor401\BluePrism\GAFG\GAFG_AgentB_Indexing\4_13_2022\Input\Notification Email_Email_April 2022.xlsx")
splitted_folder_path=(r"\\Bpspfilnor401\BluePrism\GAFG\GAFG_AgentB_Indexing\4_13_2022\SPLIT\Notification Email_Email_April 2022.pdf_SPLIT_FOLDER")
file_list = glob.glob(os.path.join(splitted_folder_path,"*pdf"))
print(file_list[0])
for file_path in file_list:
    # print(file_path)
    agent_code_dict[file_path]= [pfr.extract_agent_code(pfr.get_text_from_pdf_into_list(file_path)), get_top_right_agent_code(file_path)]
print(agent_code_dict)
df = pd.DataFrame(data=agent_code_dict)
# df = pd.DataFrame(data=agent_code_dict, index=[0])

df = (df.T)

print (df)

df.to_excel(input_file_path)
eop.delete_first_row_from_Sheet1(input_file_path)

# %%
# Code for master excel input  file creation for agent codes

import excel_others_operations as eoo
import pdf_read as pdfr
import glob
import os
# from os.path import join

def get_top_right_agent_code(file):
    #source: file:///C://Users//kulra//OneDrive/Desktop/ilovepdf_split/12%202021%20120%20Day%20OS%20Checks%2005%2018%2021%20to%2008%2007%2021%20%20143%202%20pg-1.pdf
    table = cam.read_pdf(file, pages = '1', flavor = 'stream')
    print("table[0] ", table[0])
    top_right_agent_code = table[0].df.iat[0,1]
    if (top_right_agent_code == "" or top_right_agent_code == None):
        raise Exception("Agent Code Not found")
    else:
        print(table[0].df.iat[0,1])
        return top_right_agent_code

import pandas as pd
master_csv= (r"\\Bpspfilnor401\BluePrism\GAFG\GAFG_AgentB_Indexing\4_13_2022\Master_Excel_AgentB_4_13_2022.csv")
master_excel= (r"\\Bpspfilnor401\BluePrism\GAFG\GAFG_AgentB_Indexing\4_13_2022\Master_Excel_AgentB_4_13_2022.xlsx")

df=pd.read_csv(master_csv)
# df=pd.read_excel(master_excel)
# df=pd.read_csv(master_excel)
# print(df)



pfr=pdfr.PdfRead()
eop=eoo.ExcelAndPandasOperation()

for index, row in df.iterrows():
    # print (row["SPLITTED FOLDER NAME"], row["INPUT FILENAME"])
    file_list = glob.glob(os.path.join(row["SPLITTED FOLDER NAME"],"*pdf"))
    # print(file_list[0])
    print("row[PDF NAME] ",row["PDF NAME"])
    agent_code_dict={"Path":"Agent Code"}
    for file in file_list:
        
        try:
            # agent_code_dict[file]=pfr.get_policy_no_from_table(file)

            agent_code_dict[file]= pfr.get_top_right_agent_code(file)
        except Exception as e:
            print("error")
            print(e)
            agent_code_dict[file]= pfr.get_data_after_colon_agent_code(pfr.get_text_from_pdf_into_list(file))

            # agent_code_dict[file]= pfr.get_data_after_colon_contract_number(pfr.get_text_from_pdf_into_list(file))
            # agent_code_dict[file]=pfr.get_policy_no_from_table(file)

            # agent_code_dict[file]=get_top_right_agent_code(file)
        # else:
        #     agent_code_dict[file]=pfr.get_policy_no_from_table(file)


    
    df = pd.DataFrame(data=agent_code_dict, index=[0])

    df = (df.T)

    # print (df)

    df.to_excel(row["INPUT FILENAME"])
    eop.delete_first_row_from_Sheet1(row["INPUT FILENAME"])
    print("row[INPUT FILENAME]" ,row['INPUT FILENAME'])
    # agent_code_dict={}
# Out:
# row[PDF NAME]  Debt rolled to Upline_ALL_April 2022.pdf
# 0000102728
# 0000007241
# 0000012900
# 0000007241
# row[INPUT FILENAME] \\Bpspfilnor401\BluePrism\GAFG\GAFG_AgentB_Indexing\4_13_2022\Input\Debt rolled to Upline_ALL_April 2022.xlsx
# row[PDF NAME]  Notification Email_Written_April 2022.pdf
# 0000105738
# row[INPUT FILENAME] \\Bpspfilnor401\BluePrism\GAFG\GAFG_AgentB_Indexing\4_13_2022\Input\Notification Email_Written_April 2022.xlsx
# row[PDF NAME]  Notification Letter #1_ALL_April 2022.pdf
# 0000001090
# 0000100464
# 0000111340
# 0000012701
# 0000002083
# 0000088798
# 0000052435
# 0000007241
# 0000005367
# 0000007076
# 0000007076
# 0000007241
# 0000101391
# 0000001946
# row[INPUT FILENAME] \\Bpspfilnor401\BluePrism\GAFG\GAFG_AgentB_Indexing\4_13_2022\Input\Notification Letter #1_ALL_April 2022.xlsx
# row[PDF NAME]  Notification Letter #2_ALL_April 2022.pdf
# 0000007241
# 0000000499
# 0000001093
# 0000108970
# 0000007241
# 0000000602
# 0000000562
# 0000001946
# 0000088872
# 0000102914
# 0000007241
# 0000001093
# 0000000618
# row[INPUT FILENAME] \\Bpspfilnor401\BluePrism\GAFG\GAFG_AgentB_Indexing\4_13_2022\Input\Notification Letter #2_ALL_April 2022.xlsx
# row[PDF NAME]  Notification Letter #3_ALL_April 2022.pdf
# 0000106172
# 0000108536
# 0000003881
# 0000102462
# 0000007241
# 0000012900
# 0000007241
# 0000012902
# 0000007241
# 0000003726
# 0000003881
# row[INPUT FILENAME] \\Bpspfilnor401\BluePrism\GAFG\GAFG_AgentB_Indexing\4_13_2022\Input\Notification Letter #3_ALL_April 2022.xlsx
# row[PDF NAME]  Notification Letter_TERM-COLL_ALL_April 2022.pdf
# 0000001946
# row[INPUT FILENAME] \\Bpspfilnor401\BluePrism\GAFG\GAFG_AgentB_Indexing\4_13_2022\Input\Notification Letter_TERM-COLL_ALL_April 2022.xlsx
# row[PDF NAME]  Notification Letter_TERM-ROLL_ALL_April 2022.pdf
# 0000102728
# 0000007241
# 0000012900
# 0000007241
# row[INPUT FILENAME] \\Bpspfilnor401\BluePrism\GAFG\GAFG_AgentB_Indexing\4_13_2022\Input\Notification Letter_TERM-ROLL_ALL_April 2022.xlsx
# row[PDF NAME]  PG2_Notification Letter #1_ALL_April 2022.pdf
# 0000002764
# 0000103128
# 0000107308
# 0000111543
# 0000107283
# 0000112953
# 0000006237
# 0000015198
# 0000102390
# row[INPUT FILENAME] \\Bpspfilnor401\BluePrism\GAFG\GAFG_AgentB_Indexing\4_13_2022\Input\PG2_Notification Letter #1_ALL_April 2022.xlsx
# row[PDF NAME]  PG2_Notification Letter #2_ALL_April 2022.pdf
# 0000001454
# 0000013484
# 0000020454
# 0000113602
# 0000109091
# 0000110853
# 0000000477
# 0000013108
# 0000101228
# 0000109773
# row[INPUT FILENAME] \\Bpspfilnor401\BluePrism\GAFG\GAFG_AgentB_Indexing\4_13_2022\Input\PG2_Notification Letter #2_ALL_April 2022.xlsx
# row[PDF NAME]  PG2_Notification Letter #3_ALL_April 2022.pdf
# 0000109967
# 0000052006
# 0000112398
# 0000103348
# 0000055789
# 0000104415
# row[INPUT FILENAME] \\Bpspfilnor401\BluePrism\GAFG\GAFG_AgentB_Indexing\4_13_2022\Input\PG2_Notification Letter #3_ALL_April 2022.xlsx
# row[PDF NAME]  PG2_Notification Letter_TERM-COLL_ALL_April 2022.pdf
# 0000102360
# row[INPUT FILENAME] \\Bpspfilnor401\BluePrism\GAFG\GAFG_AgentB_Indexing\4_13_2022\Input\PG2_Notification Letter_TERM-COLL_ALL_April 2022.xlsx
# row[PDF NAME]  PG2_Notification Letter_TERM-ROLL_ALL_April 2022.pdf
# 0000104340
# 0000100357
# row[INPUT FILENAME] \\Bpspfilnor401\BluePrism\GAFG\GAFG_AgentB_Indexing\4_13_2022\Input\PG2_Notification Letter_TERM-ROLL_ALL_April 2022.xlsx
# row[PDF NAME]  Notification Email_Email_April 2022.pdf
# error
# Agent Code Not found
# Agent Codes:  0000105738
# error
# Agent Code Not found
# Agent Codes:  0000105307
# error
# Agent Code Not found
# Agent Codes:  0000106237
# error
# Agent Code Not found
# Agent Codes:  0000114218
# error
# Agent Code Not found
# Agent Codes:  0000043016
# error
# Agent Code Not found
# Agent Codes:  0000001128
# error
# Agent Code Not found
# Agent Codes:  0000006652
# error
# Agent Code Not found
# Agent Codes:  0000045105
# error
# Agent Code Not found
# Agent Codes:  0000010997
# error
# Agent Code Not found
# Agent Codes:  0000107363
# error
# Agent Code Not found
# Agent Codes:  0000102914
# error
# Agent Code Not found
# Agent Codes:  0000111982
# error
# Agent Code Not found
# Agent Codes:  0000000536
# error
# Agent Code Not found
# Agent Codes:  0000100850
# error
# Agent Code Not found
# Agent Codes:  0000109216
# error
# Agent Code Not found
# Agent Codes:  0000102905
# error
# index 1 is out of bounds for axis 0 with size 1
# None
# UserWarning: No tables found in table area 1 [stream.py:365]
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# File ~\AppData\Local\Programs\Python\Python310\lib\site-packages\pandas\core\indexes\range.py:929, in RangeIndex.__getitem__(self, key)
#     928 try:
# --> 929     return self._range[new_key]
#     930 except IndexError as err:
#
# IndexError: range object index out of range
#
# The above exception was the direct cause of the following exception:
#
# IndexError                                Traceback (most recent call last)
# Input In [3], in <cell line: 34>()
#      42 try:
#      43     # agent_code_dict[file]=pfr.get_policy_no_from_table(file)
# ---> 45     agent_code_dict[file]= pfr.get_top_right_agent_code(file)
#      46 except Exception as e:
#
# File ~\Desktop\Python Projects\pdf_read.py:30, in PdfRead.get_top_right_agent_code(self, file)
#      29 table = cam.read_pdf(file, pages = '1', flavor = 'stream')
# ---> 30 top_right_agent_code = table[0].df.iat[0,1]
#      31 if (top_right_agent_code == "" or top_right_agent_code == None):
#
# File ~\AppData\Local\Programs\Python\Python310\lib\site-packages\pandas\core\indexing.py:2221, in _ScalarAccessIndexer.__getitem__(self, key)
#    2220 key = self._convert_key(key)
# -> 2221 return self.obj._get_value(*key, takeable=self._takeable)
#
# File ~\AppData\Local\Programs\Python\Python310\lib\site-packages\pandas\core\frame.py:3612, in DataFrame._get_value(self, index, col, takeable)
#    3611 if takeable:
# -> 3612     series = self._ixs(col, axis=1)
#    3613     return series._values[index]
#
# File ~\AppData\Local\Programs\Python\Python310\lib\site-packages\pandas\core\frame.py:3439, in DataFrame._ixs(self, i, axis)
#    3437 # icol
#    3438 else:
# -> 3439     label = self.columns[i]
#    3441     col_mgr = self._mgr.iget(i)
#
# File ~\AppData\Local\Programs\Python\Python310\lib\site-packages\pandas\core\indexes\range.py:931, in RangeIndex.__getitem__(self, key)
#     930     except IndexError as err:
# --> 931         raise IndexError(
#     932             f"index {key} is out of bounds for axis 0 with size {len(self)}"
#     933         ) from err
#     934 elif is_scalar(key):
#
# IndexError: index 1 is out of bounds for axis 0 with size 1
#
# During handling of the above exception, another exception occurred:
#
# AttributeError                            Traceback (most recent call last)
# Input In [3], in <cell line: 34>()
#      47         print("error")
#      48         print(e)
# ---> 49         agent_code_dict[file]= pfr.get_data_after_colon_agent_code(pfr.get_text_from_pdf_into_list(file))
#      51         # agent_code_dict[file]= pfr.get_data_after_colon_contract_number(pfr.get_text_from_pdf_into_list(file))
#      52         # agent_code_dict[file]=pfr.get_policy_no_from_table(file)
#      53
#      54         # agent_code_dict[file]=get_top_right_agent_code(file)
#      55     # else:
#      56     #     agent_code_dict[file]=pfr.get_policy_no_from_table(file)
#      60 df = pd.DataFrame(data=agent_code_dict, index=[0])
#
# File ~\Desktop\Python Projects\pdf_read.py:75, in PdfRead.get_data_after_colon_agent_code(self, text_list)
#      73 agent_code = self.find_agent_code_line(text_list)
#      74 print(agent_code)
# ---> 75 agent_code = agent_code.partition(":")[2]
#      76 # agent_code = agent_code.split(":")[1]
#      77 agent_code = agent_code.strip()
#
# AttributeError: 'NoneType' object has no attribute 'partition'

# %%
import glob
import camelot as cam
import fitz


folder=glob.glob(r"\\Bpspfilnor401\BluePrism\WCT\Correspb Indexing\4_16_2022\SPLIT\May 2022 AURA 144 one pg.pdf_SPLIT_FOLDER\*pdf")

pdf_path=r"\\Bpspfilnor401\BluePrism\WCT\Correspb Indexing\4_16_2022\SPLIT\May 2022 AURA 144 one pg.pdf_SPLIT_FOLDER\*pdf"

for pdf_path in folder:
    table = cam.read_pdf(pdf_path, pages = '1', flavor = 'stream')
    # print(table[0])
    # doc = fitz.open(pdf_path)
    # # print ("number of pages: %i" % doc.pageCount)
    # #print(doc.metadata)

    # page = doc.load_page(0)
    # page_text = page.get_text("text")
    # print(page_text)



# # print (folder)
# for files_path in folder:
#     contract_number=pfr.get_data_after_colon_contract_number(pfr.get_text_from_pdf_into_list(files_path))
#     print(contract_number)

# %%
# Code for master excel input  file creation for Policy Number

import excel_others_operations as eoo
import pdf_read as pdfr
import glob
import pdf_read_OCR as pocr
# from os.path import join


import pandas as pd
master_csv= (r"\\Bpspfilnor401\BluePrism\WCT\Correspb Indexing\4_16_2022\Master_Excel_WCT_4_16_2022.csv")
master_excel= (r"\\Bpspfilnor401\BluePrism\GAFG\GAFG_AgentB_Indexing\4_13_2022\Master_Excel_AgentB_4_13_2022.xlsx")

df=pd.read_csv(master_csv)
# df=pd.read_excel(master_excel)
# df=pd.read_csv(master_excel)
# print(df)



pfr=pdfr.PdfRead()
eop=eoo.ExcelAndPandasOperation()

for index, row in df.iterrows():
    # print (row["SPLITTED FOLDER NAME"], row["INPUT FILENAME"])
    file_list = glob.glob(os.path.join(row["SPLITTED FOLDER NAME"],"*pdf"))
    # print(file_list[0])
    print(row["PDF NAME"])
    agent_code_dict={"Path":"Policy Number"}
    for file in file_list:
        
        try:
            # agent_code_dict[file]=pfr.get_policy_no_from_table(file)

            agent_code_dict[file]= pfr.get_data_after_colon_contract_number(pocr.get_text_from_any_pdf_into_list(file))
        except Exception as e:
            print("error")
            print(e)
            # agent_code_dict[file]= pfr.get_data_after_colon_agent_code(pfr.get_text_from_pdf_into_list(file))

            agent_code_dict[file]= pfr.get_data_after_colon_contract_number(pfr.get_text_from_pdf_into_list(file))
            # agent_code_dict[file]=pfr.get_policy_no_from_table(file)

            # agent_code_dict[file]=get_top_right_agent_code(file)
        # else:
        #     agent_code_dict[file]=pfr.get_policy_no_from_table(file)


    
    df = pd.DataFrame(data=agent_code_dict, index=[0])

    df = (df.T)

    # print (df)

    df.to_excel(row["INPUT FILENAME"])
    eop.delete_first_row_from_Sheet1(row["INPUT FILENAME"])
    print(row['INPUT FILENAME'])
    # agent_code_dict={}
# Out:
# May 2022 AURA 144 one pg.pdf
# Contract: C24300366A
# Contract: C24300366A
# Contract: C28009036A
# Contract: C28009036A
# Contract: C28020295A
# Contract: C28020295A
# Contract: C28047536A
# Contract: C28047536A
# Contract: C24003876A
# Contract: C24003876A
# Contract: SP737
# Contract: SP737
# Contract: C24300424A
# Contract: C24300424A
# Contract: C28019574A
# Contract: C28019574A
# Contract: C28059904A
# Contract: C28059904A
# Contract: A0614
# Contract: A0614
# Contract: C28064283A
# Contract: C28064283A
# Contract: C28077229A
# Contract: C28077229A
# Contract: C22323868A
# Contract: C22323868A
# Contract: C28047536A
# Contract: C28047536A
# Contract: C28009036A
