# %%
import pandas as pd
master_csv= (r"\\Bpspfilnor401\BluePrism\GAFG\GAFG_AgentB_Indexing\4_13_2022\Master_Excel_AgentB_4_13_2022.csv")
master_excel= (r"\\Bpspfilnor401\BluePrism\GAFG\GAFG_AgentB_Indexing\4_13_2022\Master_Excel_AgentB_4_13_2022.xlsx")

df=pd.read_csv(master_csv)
# df=pd.read_excel(master_excel)
# df=pd.read_csv(master_excel)
# print(df)

# %%
import files_folder_operations as ffo
ff=ffo.FilesAndFolderOperations() 

import pdf_read as pdfr

# import pdf_read as pdfr
# import files_folder_operations as ffo
import pandas as pd
pfr=pdfr.PdfRead()


agent_code_dictionary={"Path":"Agent Code"}


# files = ff.get_files_recursively(r"\\Bpspfilnor401\BluePrism\GAFG\GAFG_AgentB_Indexing\4_7_2022\SPLIT\April 2022 AML Term Notice_Clean-up.pdf_SPLIT_FOLDER")
# print(files)
# filess=[]
# filess=files
# print(filess)

import glob
file_list = glob.glob(r"\\Bpspfilnor401\BluePrism\GAFG\GAFG_AgentB_Indexing\4_13_2022\SPLIT\Debt rolled to Upline_ALL_April 2022.pdf_SPLIT_FOLDER\*pdf")
print(file_list)
print(agent_code_dictionary)
# Out:
# ['\\\\Bpspfilnor401\\BluePrism\\GAFG\\GAFG_AgentB_Indexing\\4_13_2022\\SPLIT\\Debt rolled to Upline_ALL_April 2022.pdf_SPLIT_FOLDER\\Debt rolled to Upline_ALL_April 2022.pdf - Page 1.pdf', '\\\\Bpspfilnor401\\BluePrism\\GAFG\\GAFG_AgentB_Indexing\\4_13_2022\\SPLIT\\Debt rolled to Upline_ALL_April 2022.pdf_SPLIT_FOLDER\\Debt rolled to Upline_ALL_April 2022.pdf - Page 2.pdf', '\\\\Bpspfilnor401\\BluePrism\\GAFG\\GAFG_AgentB_Indexing\\4_13_2022\\SPLIT\\Debt rolled to Upline_ALL_April 2022.pdf_SPLIT_FOLDER\\Debt rolled to Upline_ALL_April 2022.pdf - Page 3.pdf', '\\\\Bpspfilnor401\\BluePrism\\GAFG\\GAFG_AgentB_Indexing\\4_13_2022\\SPLIT\\Debt rolled to Upline_ALL_April 2022.pdf_SPLIT_FOLDER\\Debt rolled to Upline_ALL_April 2022.pdf - Page 4.pdf']
# {'Path': 'Agent Code'}

# %%
import camelot as cam
# import ghostscript
import os

for file in file_list:
    #source: file:///C://Users//kulra//OneDrive/Desktop/ilovepdf_split/12%202021%20120%20Day%20OS%20Checks%2005%2018%2021%20to%2008%2007%2021%20%20143%202%20pg-1.pdf
    table = cam.read_pdf(file, pages = '1', flavor = 'stream')
    table[0].df.iat[0,1]
    print(table[0].df.iat[0,1])
        
def get_top_right_agent_code(file):
    #source: file:///C://Users//kulra//OneDrive/Desktop/ilovepdf_split/12%202021%20120%20Day%20OS%20Checks%2005%2018%2021%20to%2008%2007%2021%20%20143%202%20pg-1.pdf
    table = cam.read_pdf(file, pages = '1', flavor = 'stream')
    top_right_agent_code = table[0].df.iat[0,1]
    print(table[0].df.iat[0,1])
    return top_right_agent_code
# Out:
# 0000102728
# 0000007241
# 0000012900
# 0000007241

# %%
import excel_others_operations as eoo
import pdf_read as pdfr
import glob 


pfr=pdfr.PdfRead()
eop=eoo.ExcelAndPandasOperation()


agent_code_dict={"Path": ["Agent Code" , "Top Right Agent Code"]}

input_file_path =(r"\\Bpspfilnor401\BluePrism\GAFG\GAFG_AgentB_Indexing\4_13_2022\Input\Notification Email_Email_April 2022.xlsx")
splitted_folder_path=(r"\\Bpspfilnor401\BluePrism\GAFG\GAFG_AgentB_Indexing\4_13_2022\SPLIT\Notification Email_Email_April 2022.pdf_SPLIT_FOLDER")
file_list = glob.glob(os.path.join(splitted_folder_path,"*pdf"))
print(file_list[0])
for file_path in file_list:
    # print(file_path)
    agent_code_dict[file_path]= [pfr.extract_agent_code(pfr.get_text_from_pdf_into_list(file_path)), get_top_right_agent_code(file_path)]
print(agent_code_dict)
df = pd.DataFrame(data=agent_code_dict)
# df = pd.DataFrame(data=agent_code_dict, index=[0])

df = (df.T)

print (df)

df.to_excel(input_file_path)
eop.delete_first_row_from_Sheet1(input_file_path)
# Out:
# \\Bpspfilnor401\BluePrism\GAFG\GAFG_AgentB_Indexing\4_13_2022\SPLIT\Notification Email_Email_April 2022.pdf_SPLIT_FOLDER\Notification Email_Email_April 2022.pdf - Page 1.pdf
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# c:\Users\z-lifebot1\Desktop\Python Projects\input_file_creation_from_master_excel.ipynb Cell 4' in <cell line: 16>()
#      <a href='vscode-notebook-cell:/c%3A/Users/z-lifebot1/Desktop/Python%20Projects/input_file_creation_from_master_excel.ipynb#ch0000003?line=14'>15</a> print(file_list[0])
#      <a href='vscode-notebook-cell:/c%3A/Users/z-lifebot1/Desktop/Python%20Projects/input_file_creation_from_master_excel.ipynb#ch0000003?line=15'>16</a> for file_path in file_list:
#      <a href='vscode-notebook-cell:/c%3A/Users/z-lifebot1/Desktop/Python%20Projects/input_file_creation_from_master_excel.ipynb#ch0000003?line=16'>17</a>     # print(file_path)
# ---> <a href='vscode-notebook-cell:/c%3A/Users/z-lifebot1/Desktop/Python%20Projects/input_file_creation_from_master_excel.ipynb#ch0000003?line=17'>18</a>     agent_code_dict[file_path]= [pfr.extract_agent_code(pfr.get_text_from_pdf_into_list(file_path)), get_top_right_agent_code(file_path)]
#      <a href='vscode-notebook-cell:/c%3A/Users/z-lifebot1/Desktop/Python%20Projects/input_file_creation_from_master_excel.ipynb#ch0000003?line=18'>19</a> print(agent_code_dict)
#      <a href='vscode-notebook-cell:/c%3A/Users/z-lifebot1/Desktop/Python%20Projects/input_file_creation_from_master_excel.ipynb#ch0000003?line=19'>20</a> df = pd.DataFrame(data=agent_code_dict)
#
# NameError: name 'get_top_right_agent_code' is not defined

# %%
import excel_others_operations as eoo
import pdf_read as pdfr
import glob
# from os.path import join

import pandas as pd
master_csv= (r"\\Bpspfilnor401\BluePrism\WCT\Correspb Indexing\4_16_2022\Master_Excel_WCT_4_16_2022.csv")
master_excel= (r"\\Bpspfilnor401\BluePrism\GAFG\GAFG_AgentB_Indexing\4_13_2022\Master_Excel_AgentB_4_13_2022.xlsx")

df=pd.read_csv(master_csv)
# df=pd.read_excel(master_excel)
# df=pd.read_csv(master_excel)
# print(df)



pfr=pdfr.PdfRead()
eop=eoo.ExcelAndPandasOperation()

for index, row in df.iterrows():
    # print (row["SPLITTED FOLDER NAME"], row["INPUT FILENAME"])
    file_list = glob.glob(os.path.join(row["SPLITTED FOLDER NAME"],"*pdf"))
    # print(file_list[0])
    print(row["PDF NAME"])
    agent_code_dict={"Path":"Policy Number"}
    for file in file_list:
        
        try:
            # agent_code_dict[file]=pfr.get_policy_no_from_table(file)

            agent_code_dict[file]= pfr.get_data_after_colon_contract_number(pfr.get_text_from_pdf_into_list(file))
        except Exception as e:
            print("error")
            print(e)
            # agent_code_dict[file]= pfr.get_data_after_colon_contract_number(pfr.get_text_from_pdf_into_list(file))
            # agent_code_dict[file]=pfr.get_policy_no_from_table(file)

            # agent_code_dict[file]=get_top_right_agent_code(file)
        # else:
        #     agent_code_dict[file]=pfr.get_policy_no_from_table(file)


    
    df = pd.DataFrame(data=agent_code_dict, index=[0])

    df = (df.T)

    # print (df)

    df.to_excel(row["INPUT FILENAME"])
    eop.delete_first_row_from_Sheet1(row["INPUT FILENAME"])
    print(row['INPUT FILENAME'])
    # agent_code_dict={}
# Out:
# May 2022 AURA 144 one pg.pdf
# None
# error
# local variable 'agent_code' referenced before assignment
# None
# error
# local variable 'agent_code' referenced before assignment
# None
# error
# local variable 'agent_code' referenced before assignment
# None
# error
# local variable 'agent_code' referenced before assignment
# None
# error
# local variable 'agent_code' referenced before assignment
# None
# error
# local variable 'agent_code' referenced before assignment
# None
# error
# local variable 'agent_code' referenced before assignment
# None
# error
# local variable 'agent_code' referenced before assignment
# None
# error
# local variable 'agent_code' referenced before assignment
# None
# error
# local variable 'agent_code' referenced before assignment
# None
# error
# local variable 'agent_code' referenced before assignment
# None
# error
# local variable 'agent_code' referenced before assignment
# None
# error
# local variable 'agent_code' referenced before assignment
# None
# error
# local variable 'agent_code' referenced before assignment
# None
# error
# local variable 'agent_code' referenced before assignment
# None
# error
# local variable 'agent_code' referenced before assignment
# None
# error
# local variable 'agent_code' referenced before assignment
# None
# error
# local variable 'agent_code' referenced before assignment
# None
# error
# local variable 'agent_code' referenced before assignment
# None
# error
# local variable 'agent_code' referenced before assignment
# None
# error
# local variable 'agent_code' referenced before assignment
# None
# error
# local variable 'agent_code' referenced before assignment
# None
# error
# local variable 'agent_code' referenced before assignment
# None
# error
# local variable 'agent_code' referenced before assignment
# None
# error
# local variable 'agent_code' referenced before assignment
# None
# error
# local variable 'agent_code' referenced before assignment
# None
# error
# local variable 'agent_code' referenced before assignment
# None
# error
# local variable 'agent_code' referenced before assignment
# None
# error
# local variable 'agent_code' referenced before assignment
# None
# error
# local variable 'agent_code' referenced before assignment
# None
# error
# local variable 'agent_code' referenced before assignment
# None
# error
# local variable 'agent_code' referenced before assignment
# None
# error
# local variable 'agent_code' referenced before assignment
# None
# error
# local variable 'agent_code' referenced before assignment
# None
# error
# local variable 'agent_code' referenced before assignment
# None
# error
# local variable 'agent_code' referenced before assignment
# None
# error
# local variable 'agent_code' referenced before assignment
# None
# error
# local variable 'agent_code' referenced before assignment
# None
# error
# local variable 'agent_code' referenced before assignment
# None
# error
# local variable 'agent_code' referenced before assignment
# None
# error
# local variable 'agent_code' referenced before assignment
# None
# error
# local variable 'agent_code' referenced before assignment
# None
# error
# local variable 'agent_code' referenced before assignment
# None
# error
# local variable 'agent_code' referenced before assignment
# None
# error
# local variable 'agent_code' referenced before assignment
# None
# error
# local variable 'agent_code' referenced before assignment
# None
# error
# local variable 'agent_code' referenced before assignment
# None
# error
# local variable 'agent_code' referenced before assignment
# None
# error
# local variable 'agent_code' referenced before assignment
# None
# error
# local variable 'agent_code' referenced before assignment
# None
# error
# local variable 'agent_code' referenced before assignment
# None
# error
# local variable 'agent_code' referenced before assignment
# None
# error
# local variable 'agent_code' referenced before assignment
# None
# error
# local variable 'agent_code' referenced before assignment
# None
# error
# local variable 'agent_code' referenced before assignment
# None
# error
# local variable 'agent_code' referenced before assignment
# None
# error
# local variable 'agent_code' referenced before assignment
# None
# error
# local variable 'agent_code' referenced before assignment
# None
# error
# local variable 'agent_code' referenced before assignment
# None
# error
# local variable 'agent_code' referenced before assignment
# None
# error
# local variable 'agent_code' referenced before assignment
# None
# error
# local variable 'agent_code' referenced before assignment
# None
# error
# local variable 'agent_code' referenced before assignment
# None
# error
# local variable 'agent_code' referenced before assignment
# None
# error
# local variable 'agent_code' referenced before assignment
# None
# error
# local variable 'agent_code' referenced before assignment
# None
# error
# local variable 'agent_code' referenced before assignment
# None
# error
# local variable 'agent_code' referenced before assignment
# None
# error
# local variable 'agent_code' referenced before assignment
# None
# error
# local variable 'agent_code' referenced before assignment
# None
# error
# local variable 'agent_code' referenced before assignment
# None
# error
# local variable 'agent_code' referenced before assignment
# None
# error
# local variable 'agent_code' referenced before assignment
# None
# error
# local variable 'agent_code' referenced before assignment
# None
# error
# local variable 'agent_code' referenced before assignment
# None
# error
# local variable 'agent_code' referenced before assignment
# None
# error
# local variable 'agent_code' referenced before assignment
# None
# error
# local variable 'agent_code' referenced before assignment
# None
# error
# local variable 'agent_code' referenced before assignment
# None
# error
# local variable 'agent_code' referenced before assignment
# None
# error
# local variable 'agent_code' referenced before assignment
# None
# error
# local variable 'agent_code' referenced before assignment
# None
# error
# local variable 'agent_code' referenced before assignment
# None
# error
# local variable 'agent_code' referenced before assignment
# None
# error
# local variable 'agent_code' referenced before assignment
# None
# error
# local variable 'agent_code' referenced before assignment
# None
# error
# local variable 'agent_code' referenced before assignment
# None
# error
# local variable 'agent_code' referenced before assignment
# None
# error
# local variable 'agent_code' referenced before assignment
# None
# error
# local variable 'agent_code' referenced before assignment
# None
# error
# local variable 'agent_code' referenced before assignment
# None
# error
# local variable 'agent_code' referenced before assignment
# None
# error
# local variable 'agent_code' referenced before assignment
# None
# error
# local variable 'agent_code' referenced before assignment
# None
# error
# local variable 'agent_code' referenced before assignment
# None
# error
# local variable 'agent_code' referenced before assignment
# None
# error
# local variable 'agent_code' referenced before assignment
# None
# error
# local variable 'agent_code' referenced before assignment
# None
# error
# local variable 'agent_code' referenced before assignment
# None
# error
# local variable 'agent_code' referenced before assignment
# None
# error
# local variable 'agent_code' referenced before assignment
# None
# error
# local variable 'agent_code' referenced before assignment
# None
# error
# local variable 'agent_code' referenced before assignment
# None
# error
# local variable 'agent_code' referenced before assignment
# None
# error
# local variable 'agent_code' referenced before assignment
# None
# error
# local variable 'agent_code' referenced before assignment
# None
# error
# local variable 'agent_code' referenced before assignment
# None
# error
# local variable 'agent_code' referenced before assignment
# None
# error
# local variable 'agent_code' referenced before assignment
# None
# error
# local variable 'agent_code' referenced before assignment
# None
# error
# local variable 'agent_code' referenced before assignment
# None
# error
# local variable 'agent_code' referenced before assignment
# None
# error
# local variable 'agent_code' referenced before assignment
# None
# error
# local variable 'agent_code' referenced before assignment
# None
# error
# local variable 'agent_code' referenced before assignment
# None
# error
# local variable 'agent_code' referenced before assignment
# None
# error
# local variable 'agent_code' referenced before assignment
# None
# error
# local variable 'agent_code' referenced before assignment
# None
# error
# local variable 'agent_code' referenced before assignment
# None
# error
# local variable 'agent_code' referenced before assignment
# None
# error
# local variable 'agent_code' referenced before assignment
# None
# error
# local variable 'agent_code' referenced before assignment
# None
# error
# local variable 'agent_code' referenced before assignment
# None
# error
# local variable 'agent_code' referenced before assignment
# None
# error
# local variable 'agent_code' referenced before assignment
# None
# error
# local variable 'agent_code' referenced before assignment
# None
# error
# local variable 'agent_code' referenced before assignment
# None
# error
# local variable 'agent_code' referenced before assignment
# None
# error
# local variable 'agent_code' referenced before assignment
# None
# error
# local variable 'agent_code' referenced before assignment
# None
# error
# local variable 'agent_code' referenced before assignment
# None
# error
# local variable 'agent_code' referenced before assignment
# None
# error
# local variable 'agent_code' referenced before assignment
# None
# error
# local variable 'agent_code' referenced before assignment
# None
# error
# local variable 'agent_code' referenced before assignment
# None
# error
# local variable 'agent_code' referenced before assignment
# None
# error
# local variable 'agent_code' referenced before assignment
# None
# error
# local variable 'agent_code' referenced before assignment
# None
# error
# local variable 'agent_code' referenced before assignment
# None
# error
# local variable 'agent_code' referenced before assignment
# None
# error
# local variable 'agent_code' referenced before assignment
# None
# error
# local variable 'agent_code' referenced before assignment
# None
# error
# local variable 'agent_code' referenced before assignment
# None
# error
# local variable 'agent_code' referenced before assignment
# \\Bpspfilnor401\BluePrism\WCT\Correspb Indexing\4_16_2022\Input\May 2022 AURA 144 one pg.pdf_WCT_Indexing_Input_File_.xlsx
# May 2022 AURA Canada 2 one pg.pdf
# None
# error
# local variable 'agent_code' referenced before assignment
# None
# error
# local variable 'agent_code' referenced before assignment
# \\Bpspfilnor401\BluePrism\WCT\Correspb Indexing\4_16_2022\Input\May 2022 AURA Canada 2 one pg.pdf_WCT_Indexing_Input_File_.xlsx
# May 2022 AURA Foreign 19 one pg.pdf
# None
# error
# local variable 'agent_code' referenced before assignment
# None
# error
# local variable 'agent_code' referenced before assignment
# None
# error
# local variable 'agent_code' referenced before assignment
# None
# error
# local variable 'agent_code' referenced before assignment
# None
# error
# local variable 'agent_code' referenced before assignment
# None
# error
# local variable 'agent_code' referenced before assignment
# None
# error
# local variable 'agent_code' referenced before assignment
# None
# error
# local variable 'agent_code' referenced before assignment
# None
# error
# local variable 'agent_code' referenced before assignment
# None
# error
# local variable 'agent_code' referenced before assignment
# None
# error
# local variable 'agent_code' referenced before assignment
# None
# error
# local variable 'agent_code' referenced before assignment
# None
# error
# local variable 'agent_code' referenced before assignment
# None
# error
# local variable 'agent_code' referenced before assignment
# None
# error
# local variable 'agent_code' referenced before assignment
# None
# error
# local variable 'agent_code' referenced before assignment
# None
# error
# local variable 'agent_code' referenced before assignment
# None
# error
# local variable 'agent_code' referenced before assignment
# None
# error
# local variable 'agent_code' referenced before assignment
# \\Bpspfilnor401\BluePrism\WCT\Correspb Indexing\4_16_2022\Input\May 2022 AURA Foreign 19 one pg.pdf_WCT_Indexing_Input_File_.xlsx
# May 2022 AURA NY CERTIFIED 7 one pg.pdf
# None
# error
# local variable 'agent_code' referenced before assignment
# None
# error
# local variable 'agent_code' referenced before assignment
# None
# error
# local variable 'agent_code' referenced before assignment
# None
# error
# local variable 'agent_code' referenced before assignment
# None
# error
# local variable 'agent_code' referenced before assignment
# None
# error
# local variable 'agent_code' referenced before assignment
# None
# error
# local variable 'agent_code' referenced before assignment
# \\Bpspfilnor401\BluePrism\WCT\Correspb Indexing\4_16_2022\Input\May 2022 AURA NY CERTIFIED 7 one pg.pdf_WCT_Indexing_Input_File_.xlsx
# May 2022 AVI Canada 21 one pg.pdf
# None
# error
# local variable 'agent_code' referenced before assignment
# None
# error
# local variable 'agent_code' referenced before assignment
# None
# error
# local variable 'agent_code' referenced before assignment
# None
# error
# local variable 'agent_code' referenced before assignment
# None
# error
# local variable 'agent_code' referenced before assignment
# None
# error
# local variable 'agent_code' referenced before assignment
# None
# error
# local variable 'agent_code' referenced before assignment
# None
# error
# local variable 'agent_code' referenced before assignment
# None
# error
# local variable 'agent_code' referenced before assignment
# None
# error
# local variable 'agent_code' referenced before assignment
# None
# error
# local variable 'agent_code' referenced before assignment
# None
# error
# local variable 'agent_code' referenced before assignment
# None
# error
# local variable 'agent_code' referenced before assignment
# None
# error
# local variable 'agent_code' referenced before assignment
# None
# error
# local variable 'agent_code' referenced before assignment
# None
# error
# local variable 'agent_code' referenced before assignment
# None
# error
# local variable 'agent_code' referenced before assignment
# None
# error
# local variable 'agent_code' referenced before assignment
# None
# error
# local variable 'agent_code' referenced before assignment
# None
# error
# local variable 'agent_code' referenced before assignment
# None
# error
# local variable 'agent_code' referenced before assignment
# \\Bpspfilnor401\BluePrism\WCT\Correspb Indexing\4_16_2022\Input\May 2022 AVI Canada 21 one pg.pdf_WCT_Indexing_Input_File_.xlsx
# May 2022 AVI Foreign 69 one pg.pdf
# None
# error
# local variable 'agent_code' referenced before assignment
# None
# error
# local variable 'agent_code' referenced before assignment
# None
# error
# local variable 'agent_code' referenced before assignment
# None
# error
# local variable 'agent_code' referenced before assignment
# None
# error
# local variable 'agent_code' referenced before assignment
# None
# error
# local variable 'agent_code' referenced before assignment
# None
# error
# local variable 'agent_code' referenced before assignment
# None
# error
# local variable 'agent_code' referenced before assignment
# None
# error
# local variable 'agent_code' referenced before assignment
# None
# error
# local variable 'agent_code' referenced before assignment
# None
# error
# local variable 'agent_code' referenced before assignment
# None
# error
# local variable 'agent_code' referenced before assignment
# None
# error
# local variable 'agent_code' referenced before assignment
# None
# error
# local variable 'agent_code' referenced before assignment
# None
# error
# local variable 'agent_code' referenced before assignment
# None
# error
# local variable 'agent_code' referenced before assignment
# None
# error
# local variable 'agent_code' referenced before assignment
# None
# error
# local variable 'agent_code' referenced before assignment
# None
# error
# local variable 'agent_code' referenced before assignment
# None
# error
# local variable 'agent_code' referenced before assignment
# None
# error
# local variable 'agent_code' referenced before assignment
# None
# error
# local variable 'agent_code' referenced before assignment
# None
# error
# local variable 'agent_code' referenced before assignment
# None
# error
# local variable 'agent_code' referenced before assignment
# None
# error
# local variable 'agent_code' referenced before assignment
# None
# error
# local variable 'agent_code' referenced before assignment
# None
# error
# local variable 'agent_code' referenced before assignment
# None
# error
# local variable 'agent_code' referenced before assignment
# None
# error
# local variable 'agent_code' referenced before assignment
# None
# error
# local variable 'agent_code' referenced before assignment
# None
# error
# local variable 'agent_code' referenced before assignment
# None
# error
# local variable 'agent_code' referenced before assignment
# None
# error
# local variable 'agent_code' referenced before assignment
# None
# error
# local variable 'agent_code' referenced before assignment
# None
# error
# local variable 'agent_code' referenced before assignment
# None
# error
# local variable 'agent_code' referenced before assignment
# None
# error
# local variable 'agent_code' referenced before assignment
# None
# error
# local variable 'agent_code' referenced before assignment
# None
# error
# local variable 'agent_code' referenced before assignment
# None
# error
# local variable 'agent_code' referenced before assignment
# None
# error
# local variable 'agent_code' referenced before assignment
# None
# error
# local variable 'agent_code' referenced before assignment
# None
# error
# local variable 'agent_code' referenced before assignment
# None
# error
# local variable 'agent_code' referenced before assignment
# None
# error
# local variable 'agent_code' referenced before assignment
# None
# error
# local variable 'agent_code' referenced before assignment
# None
# error
# local variable 'agent_code' referenced before assignment
# None
# error
# local variable 'agent_code' referenced before assignment
# None
# error
# local variable 'agent_code' referenced before assignment
# None
# error
# local variable 'agent_code' referenced before assignment
# None
# error
# local variable 'agent_code' referenced before assignment
# None
# error
# local variable 'agent_code' referenced before assignment
# None
# error
# local variable 'agent_code' referenced before assignment
# None
# error
# local variable 'agent_code' referenced before assignment
# None
# error
# local variable 'agent_code' referenced before assignment
# None
# error
# local variable 'agent_code' referenced before assignment
# None
# error
# local variable 'agent_code' referenced before assignment
# None
# error
# local variable 'agent_code' referenced before assignment
# None
# error
# local variable 'agent_code' referenced before assignment
# None
# error
# local variable 'agent_code' referenced before assignment
# None
# error
# local variable 'agent_code' referenced before assignment
# None
# error
# local variable 'agent_code' referenced before assignment
# None
# error
# local variable 'agent_code' referenced before assignment
# None
# error
# local variable 'agent_code' referenced before assignment
# None
# error
# local variable 'agent_code' referenced before assignment
# None
# error
# local variable 'agent_code' referenced before assignment
# None
# error
# local variable 'agent_code' referenced before assignment
# None
# error
# local variable 'agent_code' referenced before assignment
# None
# error
# local variable 'agent_code' referenced before assignment
# \\Bpspfilnor401\BluePrism\WCT\Correspb Indexing\4_16_2022\Input\May 2022 AVI Foreign 69 one pg.pdf_WCT_Indexing_Input_File_.xlsx

# %%
import glob
folder=glob.glob(r"\\Bpspfilnor401\BluePrism\WCT\Correspb Indexing\4_16_2022\SPLIT\May 2022 AURA 144 one pg.pdf_SPLIT_FOLDER\*pdf")

# print (folder)
for files_path in folder:
    contract_number=pfr.get_data_after_colon_contract_number(pfr.get_text_from_pdf_into_list(files_path))
    print(contract_number)
# Out:
# None
# ---------------------------------------------------------------------------
# UnboundLocalError                         Traceback (most recent call last)
# c:\Users\z-lifebot1\Desktop\Python Projects\input_file_creation_from_master_excel.ipynb Cell 6' in <cell line: 5>()
#       <a href='vscode-notebook-cell:/c%3A/Users/z-lifebot1/Desktop/Python%20Projects/input_file_creation_from_master_excel.ipynb#ch0000005?line=3'>4</a> # print (folder)
#       <a href='vscode-notebook-cell:/c%3A/Users/z-lifebot1/Desktop/Python%20Projects/input_file_creation_from_master_excel.ipynb#ch0000005?line=4'>5</a> for files_path in folder:
# ----> <a href='vscode-notebook-cell:/c%3A/Users/z-lifebot1/Desktop/Python%20Projects/input_file_creation_from_master_excel.ipynb#ch0000005?line=5'>6</a>     contract_number=pfr.get_data_after_colon_contract_number(pfr.get_text_from_pdf_into_list(files_path))
#       <a href='vscode-notebook-cell:/c%3A/Users/z-lifebot1/Desktop/Python%20Projects/input_file_creation_from_master_excel.ipynb#ch0000005?line=6'>7</a>     print(contract_number)
#
# File c:\Users\z-lifebot1\Desktop\Python Projects\pdf_read.py:74, in PdfRead.get_data_after_colon_contract_number(self, text_list)
#      <a href='file:///c%3A/Users/z-lifebot1/Desktop/Python%20Projects/pdf_read.py?line=71'>72</a> print(contract_code)
#      <a href='file:///c%3A/Users/z-lifebot1/Desktop/Python%20Projects/pdf_read.py?line=72'>73</a> # contract_code = contract_code.partition(":")[2]
# ---> <a href='file:///c%3A/Users/z-lifebot1/Desktop/Python%20Projects/pdf_read.py?line=73'>74</a> agent_code = agent_code.split(":")[1]
#      <a href='file:///c%3A/Users/z-lifebot1/Desktop/Python%20Projects/pdf_read.py?line=74'>75</a> contract_code = contract_code.strip()
#      <a href='file:///c%3A/Users/z-lifebot1/Desktop/Python%20Projects/pdf_read.py?line=75'>76</a> return contract_code
#
# UnboundLocalError: local variable 'agent_code' referenced before assignment
